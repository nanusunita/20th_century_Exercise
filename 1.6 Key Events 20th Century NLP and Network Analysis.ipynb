# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
# Download English module

# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.7.1
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.7.1/en_core_web_sm-3.7.1-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      --------------------------------------- 0.0/12.8 MB 640.0 kB/s eta 0:00:20
#      --------------------------------------- 0.0/12.8 MB 487.6 kB/s eta 0:00:27
#      ---------------------------------------- 0.1/12.8 MB 1.1 MB/s eta 0:00:12
#      - -------------------------------------- 0.5/12.8 MB 3.7 MB/s eta 0:00:04
#      ---- ----------------------------------- 1.6/12.8 MB 7.7 MB/s eta 0:00:02
#      ------------ --------------------------- 4.1/12.8 MB 16.2 MB/s eta 0:00:01
#      ------------------- -------------------- 6.2/12.8 MB 20.9 MB/s eta 0:00:01
#      -------------------------- ------------- 8.4/12.8 MB 24.4 MB/s eta 0:00:01
#      -------------------------------- ------ 10.6/12.8 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  12.8/12.8 MB 46.7 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 40.9 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.8.0,>=3.7.2 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from en-core-web-sm==3.7.1) (3.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.0.9)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.2.3)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.66.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.32.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.7.2)
# Requirement already satisfied: jinja2 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.1.4)
# Requirement already satisfied: setuptools in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (69.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.4.0)
# Requirement already satisfied: numpy>=1.19.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.26.4)
# Requirement already satisfied: language-data>=1.2 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.2.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.0)
# Requirement already satisfied: pydantic-core==2.18.3 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.18.3)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2024.2.2)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from thinc<8.3.0,>=8.2.2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.1.4)
# Requirement already satisfied: colorama in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from typer<0.10.0,>=0.3.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (8.1.7)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from weasel<0.4.0,>=0.1.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (0.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from jinja2->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (2.1.5)
# Requirement already satisfied: marisa-trie>=0.7.7 in c:\users\bhuwandhakal\anaconda3\envs\venv_20th_century\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.8.0,>=3.7.2->en-core-web-sm==3.7.1) (1.1.1)
# [+] Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# Load spacy English module

NER = spacy.load("en_core_web_sm")

# %% [markdown]
# ## Load Key Events of 20th Century book

# %%
# Load the book

with open('Key events of 20th century.txt', 'r', errors='ignore') as file:
    data = file.read().replace('\n', '')

# %% [markdown]
# ## Data Wrangling

# %% [markdown]
# - I decided to clean the data as there are stop words and unnecessary punctuation in the data. This will give cleaner version of the text to analyze the data

# %%
# Sentence tokenization

from nltk.tokenize import sent_tokenize
tokenized_sent = sent_tokenize(data)

# %%
# Word tokenization

from nltk.tokenize import word_tokenize
tokenized_word = word_tokenize(data)

# %%
# Defining stopwords

from nltk.corpus import stopwords
stop_words = set(stopwords.words("english"))

# %%
# Removing stopwords in words

filtered_words = [] # creates an empty list
for word in tokenized_word:
    if word not in stop_words:
        filtered_words.append(word)

# %%
# Substitute all punctuation marks with a space

sans_punc = re.sub("[^a-zA-Z]",  # Search for all non-letters
                        " ",        # Replace all non-letters with spaces
                        str(filtered_words))

# %%
# Word tokenization

tokenized_word_2 = word_tokenize(sans_punc)

# %%
new_stopwords = ["And", "Then", 'n', 't', 's', 'The', 'In', 'would', 'S', 'II', 'would', 'p']

# %%
filtered = []
for word in tokenized_word_2:
    if word not in new_stopwords:
        filtered.append(word)

# %%
#Combine the words
listToStr = ' '.join([str(elem) for elem in filtered])

# %%
#Exporting Text File
with open('KeyEvents_20thCentury_WrangledData.txt', 'w') as textfile:
    textfile.write(listToStr)

# %% [markdown]
# ## Creating  NER Objects

# %%
# Creating the NER object
book = NER(listToStr)

# %%
# Visualize identified entities
displacy.render(book[27:200], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">led creation atomic bombs
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Cold War led Space Race
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  creation space based rockets
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World Wide Web
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  created These advancements played significant role citizens lives shaped st century today Events th
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     century
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  edit world beginning century edit Main article Edwardian eraThe new beginning th century marked significant changes saw
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     decade
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  herald series inventions including automobile airplane radio broadcasting From
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     First World War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  aftermath caused major changes power balance world destroying transforming powerful empires war end wars
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  I edit Main article
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     World War IArrest
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  suspect
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sarajevo
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  following Assassination Archduke Franz FerdinandThe First World War simply WWI termed
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Great War
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  contemporaries started ended war extension century whole ignited Assassination
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Sarajevo Austro Hungarian Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  heir throne
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Erzherzog Franz Ferdinand Gavrilo Princip
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  organization
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Young Bosnia Bosnian Serbs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  liberation movement This similar inciting incident st century
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bound Slavic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  nationalism help small
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Serbian
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  state
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russians
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  came aid
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Serbs
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  attacked
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Interwoven
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  alliances increasing arms race old hatreds dragged
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Europe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  war Allies known initially
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Triple Entente
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  comprised
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     British
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  Empire
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Italy
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1;

# %% [markdown]
# ## Splitting Sentence Entities

# %%
df_sentences = [] # empty shell to store results

# Loop through sentences, get entity list for each sentence
for sent in book.sents:
    entity_list = [ent.text for ent in sent.ents]
    df_sentences.append({"sentence": sent, "entities": entity_list})
    
df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(20)
# Out:
#                                              sentence  \
# 0   (Jump, contentMain, menuSearchCreate, accountL...
# 1   (encyclopediaThe, th, century, changed, world,...
# 2   (Kaiser, Wilhelm, Much, map, Europe, redrawn, ...
# 3   (However, European, revolutions, defeated, Vla...
# 4   (Many, people, saw, first, stage, end, capital...
# 5   (economic, downturn, Hitler, began, put, plan,...
# 6   (He, negotiated, annexation, Sudetenland, Germ...
# 7   (This, treaty, gave, Stalin, free, rein, take,...
# 8                        (Estonia, Latvia, Lithuania)
# 9   (well, Eastern, Poland, remain, Soviet, posses...
# 10  (Denmark, surrendered, four, days, Sweden, Sca...
# 11                                    (Vichy, France)
# 12  (However, members, escaped, French, Army, form...
# 13  (He, ordered, generals, draw, plans, invasion,...
# 14  (Therefore, Soviet, army, largely, unprepared,...
# 15  (Stalingrad, However, repeatedly, switched, tr...
# 16  (Meanwhile, Japanese, attacked, United, States...
# 17  (This, disastrous, attack, forced, Americans, ...
# 18                                          (Germany)
# 19  (However, Hitler, hoped, Japan, able, quickly,...
#
#                                              entities
# 0                                         [Wikipedia]
# 1   [World Wars, Cold War led Space Race, World Wi...
# 2   [Kaiser Wilhelm, Europe, Yugoslavia, Czechoslo...
# 3   [European, Vladimir Lenin, Joseph Stalin, Leon...
# 4   [first, Soviet Union, Dorothea Lange, Migrant ...
# 5        [Hitler, Austria Anschluss, Austria Germany]
# 6   [Sudetenland German, Czechoslovakia Munich Con...
# 7                                    [Stalin, Baltic]
# 8                        [Estonia, Latvia, Lithuania]
# 9   [Eastern Poland, Soviet, Stalin, Finland, Sovi...
# 10  [Denmark, four days, Sweden, Scandinavian, Ger...
# 11                                           [France]
# 12  [French Army, Charles de Gaulle, French, Hitle...
# 13  [Operation Sea Lion, Luftwaffe, British, Battl...
# 14  [Soviet, Stalin, Germans, German, Army Group A...
# 15  [Stalingrad However, Army, German, Stalingrad ...
# 16  [Japanese, United States, Pearl Harbor, Hawaii...
# 17    [Americans, German, US, Japan, Tripartite Pact]
# 18                                          [Germany]
# 19  [Hitler, Japan, US, Russia, Germany, Italy, Un...

# %% [markdown]
# ## Loading country names

# %%
# Import countries
country_df = pd.read_csv("country names mentioned times.csv", index_col = 0)

# %%
country_df.head()
# Out:
#   Country_name  Times mentioned
# 0  Afghanistan                1
# 1      Albania                2
# 2      Algeria                1
# 4       Angola                1
# 8    Australia                2

# %% [markdown]
# ## Filtering entities from the book

# %%
# Function to filter out entities not of interest

def filter_entity(ent_list, country_df):
    return [ent for ent in ent_list 
            if ent in list(country_df['Country_name'])]

# %%
# Check

filter_entity(["Australia"], country_df)
# Out:
# ['Australia']

# %%
df_sentences['country_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, country_df))

# %%
df_sentences['country_entities'].head(20)
# Out:
# 0                                                    []
# 1     [France, Italy, Russia, Germany, Austria, Hung...
# 2                                                    []
# 3                                                    []
# 4     [Germany, Italy, Germany, Germany, Germany, Ge...
# 5                                                    []
# 6     [Spain, France, Poland, Poland, France, German...
# 7                                                    []
# 8                          [Estonia, Latvia, Lithuania]
# 9     [Finland, Germany, Poland, Luxembourg, Norway,...
# 10            [Denmark, Sweden, France, France, France]
# 11                                             [France]
# 12                              [France, Italy, Greece]
# 13                   [Germany, Greece, Albania, Greece]
# 14                    [Libya, Egypt, Egypt, Iraq, Iran]
# 15                                                   []
# 16                                                   []
# 17                                              [Japan]
# 18                                            [Germany]
# 19                      [Japan, Russia, Germany, Italy]
# Name: country_entities, dtype: object

# %%
# Filter out sentences that don't have any character entities

df_sentences_filtered = df_sentences[df_sentences['country_entities'].map(len) > 0]

# %%
df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 90   (We, Can, Still, Learn, From, It, Time, Retrie...
# 91   (Retrieved, Forgotten, Reason, Why, Japan, Att...
# 98   (ONLINE, Retrieved, Andrew, Glass, August, Hir...
# 104  (Retrieved, Kirsch, Adam, April, System, Two, ...
# 113  (Preparatory, Commission, Comprehensive, Nucle...
# 114  (Retrieved, Why, Did, League, Nations, Fail, w...
# 115  (Portuguese, Africa, Oxford, Research, Encyclo...
# 117  (Africa, Retrieved, Yalta, Conference, Cold, W...
# 124  (Fall, Saigon, Time, Retrieved, Woollacott, Ma...
# 139  (Guardian, ISSN, Retrieved, Corstange, Daniel,...
#
#                                               entities country_entities
# 90   [Sino Japanese War Anti Japanese War Eight Yea...   [Italy, Japan]
# 91   [Japan, Pearl Harbor National Interest, United...   [Japan, Japan]
# 98   [Andrew Glass, August, Hirohito, Japan, Aug PO...          [Japan]
# 104  [Two, Nazi, December, Perspectives Clinical Re...         [Israel]
# 113  [BBC News, Retrieved Nuclear, Stockholm Intern...           [Iran]
# 114  [Retrieved Why Did League Nations Fail, un, St...          [India]
# 115  [Portuguese, Africa Oxford Research Encycloped...    [Afghanistan]
# 117  [Cold War, March, Roberts Geoffrey, World War ...         [Russia]
# 124  [Saigon Time, Woollacott Martin, April, Forty ...        [Vietnam]
# 139  [Guardian ISSN Retrieved Corstange, Middle Eas...          [India]

# %%
# Take only the first name of the characters

##df_sentences_filtered['country_entities'] = df_sentences_filtered['country_entities'].apply(lambda x: [item.split()[0]
                                                                                                   ## for item in x])

# %%
df_sentences_filtered.tail(10)
# Out:
#                                               sentence  \
# 90   (We, Can, Still, Learn, From, It, Time, Retrie...
# 91   (Retrieved, Forgotten, Reason, Why, Japan, Att...
# 98   (ONLINE, Retrieved, Andrew, Glass, August, Hir...
# 104  (Retrieved, Kirsch, Adam, April, System, Two, ...
# 113  (Preparatory, Commission, Comprehensive, Nucle...
# 114  (Retrieved, Why, Did, League, Nations, Fail, w...
# 115  (Portuguese, Africa, Oxford, Research, Encyclo...
# 117  (Africa, Retrieved, Yalta, Conference, Cold, W...
# 124  (Fall, Saigon, Time, Retrieved, Woollacott, Ma...
# 139  (Guardian, ISSN, Retrieved, Corstange, Daniel,...
#
#                                               entities country_entities
# 90   [Sino Japanese War Anti Japanese War Eight Yea...   [Italy, Japan]
# 91   [Japan, Pearl Harbor National Interest, United...   [Japan, Japan]
# 98   [Andrew Glass, August, Hirohito, Japan, Aug PO...          [Japan]
# 104  [Two, Nazi, December, Perspectives Clinical Re...         [Israel]
# 113  [BBC News, Retrieved Nuclear, Stockholm Intern...           [Iran]
# 114  [Retrieved Why Did League Nations Fail, un, St...          [India]
# 115  [Portuguese, Africa Oxford Research Encycloped...    [Afghanistan]
# 117  [Cold War, March, Roberts Geoffrey, World War ...         [Russia]
# 124  [Saigon Time, Woollacott Martin, April, Forty ...        [Vietnam]
# 139  [Guardian ISSN Retrieved Corstange, Middle Eas...          [India]

# %% [markdown]
# ## Creating Relationships

# %%
# Defining relationships 

# window size = 5 : this defines how many sentences will be looked at simultaneously 
relationships = [] # create an empty list

for i in range(df_sentences_filtered.index[-1]):
    end_i = min(i+5, df_sentences_filtered.index[-1])
    char_list = sum((df_sentences_filtered.loc[i: end_i].country_entities), [])
    
    # Remove duplicated characters that are next to each other
    char_unique = [char_list[i] for i in range(len(char_list)) 
                   if (i==0) or char_list[i] != char_list[i-1]]
    
    if len(char_unique) > 1:
        for idx, a in enumerate(char_unique[:-1]):
            b = char_unique[idx + 1]
            relationships.append({"source": a, "target": b})

# %%
relationship_df = pd.DataFrame(relationships)

# %%
relationship_df
# Out:
#           source       target
# 0         France        Italy
# 1          Italy       Russia
# 2         Russia      Germany
# 3        Germany      Austria
# 4        Austria      Hungary
# ..           ...          ...
# 564        India  Afghanistan
# 565  Afghanistan       Russia
# 566        India  Afghanistan
# 567  Afghanistan       Russia
# 568  Afghanistan       Russia
#
# [569 rows x 2 columns]

# %%
# Sort the cases with a- >b and b- >a
relationship_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationship_df.head(5)
# Out:
#     source   target
# 0   France    Italy
# 1    Italy   Russia
# 2  Germany   Russia
# 3  Austria  Germany
# 4  Austria  Hungary

# %%
relationship_df["value"] = 1
relationship_df = relationship_df.groupby(["source","target"], sort=False, as_index=False).sum()

relationship_df.head(10)
# Out:
#      source   target  value
# 0    France    Italy     11
# 1     Italy   Russia      2
# 2   Germany   Russia     10
# 3   Austria  Germany      2
# 4   Austria  Hungary      2
# 5  Bulgaria  Hungary      2
# 6  Bulgaria   Russia      2
# 7   Germany  Ukraine      4
# 8   Germany    Italy     19
# 9   Germany    Spain      4

# %%
# Export Relationship
relationship_df.to_csv('keyevents_20thcentury_countries_relationship.csv')
